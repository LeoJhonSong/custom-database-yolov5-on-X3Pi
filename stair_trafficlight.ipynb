# %%
import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-165-ge382d4c Python-3.10.4 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 2070 Super with Max-Q Design, 7974MiB)
# Setup complete ✅ (12 CPUs, 15.5 GB RAM, 168.6/468.1 GB disk)

# %% [markdown]
# ### 训练

# %%
# 启动tensorboard监控训练
# %load_ext tensorboard
# %tensorboard --logdir runs/train
# Out:
#       <iframe id="tensorboard-frame-ffa5681bf11b7182" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-ffa5681bf11b7182");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data stair_trafficlight.yaml --weights yolov5n.pt --cache
# Out:
# train: weights=yolov5n.pt, cfg=, data=stair_trafficlight.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 22 commits. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv5 🚀 v7.0-165-ge382d4c Python-3.10.4 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 2070 Super with Max-Q Design, 7974MiB)
#
# ...

# %% [markdown]
# ### 测试

# %%
# 以视频为数据源进行识别
# !python detect.py --weights runs/train/exp2/weights/best.pt --img 640 --conf 0.4 --source ~/Downloads/up.mp4
# Out:
# detect: weights=['runs/train/exp2/weights/best.pt'], source=/home/leo/Downloads/up.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-165-ge382d4c Python-3.10.4 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 2070 Super with Max-Q Design, 7974MiB)
#
# Fusing layers...
# Model summary: 157 layers, 1765930 parameters, 0 gradients, 4.1 GFLOPs
# video 1/1 (1/207) /home/leo/Downloads/up.mp4: 384x640 1 up_stair, 45.6ms
# video 1/1 (2/207) /home/leo/Downloads/up.mp4: 384x640 1 up_stair, 6.5ms
# video 1/1 (3/207) /home/leo/Downloads/up.mp4: 384x640 1 up_stair, 9.8ms
# ...

# %%
# 以摄像头为数据源进行识别
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source 0

# %% [markdown]
# ### 导出

# %% [markdown]
# 导出前用*models/yolo_for_export.py*的内容替换*models/yolo.py*的内容

# %%
# !python export.py --weights runs/train/exp4/weights/best.pt --data stair_trafficlight.yaml --include onnx --simplify --opset 11 --imgsz 672
# Out:
# export: data=stair_trafficlight.yaml, weights=['runs/train/exp4/weights/best.pt'], imgsz=[672], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=11, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['onnx']
# YOLOv5 🚀 v7.0-165-ge382d4c Python-3.10.4 torch-2.0.1+cu117 CPU
#
# Fusing layers...
# Model summary: 157 layers, 1765930 parameters, 0 gradients, 4.1 GFLOPs
#
# PyTorch: starting from runs/train/exp4/weights/best.pt with output shape (1, 84, 84, 30) (3.7 MB)
#
# ONNX: starting export with onnx 1.12.0...
# ============= Diagnostic Run torch.onnx.export version 2.0.1+cu117 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# ONNX: simplifying with onnx-simplifier 0.4.28...
# ...
